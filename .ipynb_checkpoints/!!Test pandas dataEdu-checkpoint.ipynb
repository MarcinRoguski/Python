# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
# %matplotlib inline

# %%
dataEdu = pd.read_csv('c://PythonScripts//BankChurners.csv', usecols = ["Education_Level"], squeeze = True)
# Out:
# C:\Users\ram\AppData\Local\Temp\ipykernel_10068\2620432233.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   dataEdu = pd.read_csv('c://PythonScripts//BankChurners.csv', usecols = ["Education_Level"], squeeze = True)

# %%
x = np.array(['"High School"', '"Unknown"', '"Doctorate"', '"College"', '"Post-Graduate"', '"Graduate"', '"Uneducated"'])
y = np.array([2013, 1519, 451, 1013, 516, 3128, 1487])
font={'size': 12}

plt.barh(x, y)
plt.show()
